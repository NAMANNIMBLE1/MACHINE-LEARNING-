# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns 
import numpy as np 
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Users\\nex20\\Downloads\\melb_data.csv\\melb_data.csv")

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of        Suburb  Address  Rooms   Type  Price  Method  SellerG   Date  Distance  \
# 0       False    False  False  False  False   False    False  False     False
# 1       False    False  False  False  False   False    False  False     False
# 2       False    False  False  False  False   False    False  False     False
# 3       False    False  False  False  False   False    False  False     False
# 4       False    False  False  False  False   False    False  False     False
# ...       ...      ...    ...    ...    ...     ...      ...    ...       ...
# 13575   False    False  False  False  False   False    False  False     False
# 13576   False    False  False  False  False   False    False  False     False
# 13577   False    False  False  False  False   False    False  False     False
# 13578   False    False  False  False  False   False    False  False     False
# 13579   False    False  False  False  False   False    False  False     False
#
# ...

# %%
df['BuildingArea'].fillna(df['BuildingArea'].mean() , inplace = True )

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea        0
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df['Car'].fillna(df['Car'].mean() , inplace = True)

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df.YearBuilt.fillna(df.YearBuilt.mean() , inplace = True)

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# YearBuilt           0
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df = df.drop(columns = ['Date','Address','Lattitude','Longtitude','Postcode','YearBuilt'])

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Distance            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# CouncilArea      1369
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df.head()
# Out:
#        Suburb  Rooms Type      Price Method SellerG  Distance  Bedroom2  \
# 0  Abbotsford      2    h  1480000.0      S  Biggin       2.5       2.0
# 1  Abbotsford      2    h  1035000.0      S  Biggin       2.5       2.0
# 2  Abbotsford      3    h  1465000.0     SP  Biggin       2.5       3.0
# 3  Abbotsford      3    h   850000.0     PI  Biggin       2.5       3.0
# 4  Abbotsford      4    h  1600000.0     VB  Nelson       2.5       3.0
#
#    Bathroom  Car  Landsize  BuildingArea CouncilArea             Regionname  \
# 0       1.0  1.0     202.0     151.96765       Yarra  Northern Metropolitan
# 1       1.0  0.0     156.0      79.00000       Yarra  Northern Metropolitan
# 2       2.0  0.0     134.0     150.00000       Yarra  Northern Metropolitan
# 3       2.0  1.0      94.0     151.96765       Yarra  Northern Metropolitan
# 4       1.0  2.0     120.0     142.00000       Yarra  Northern Metropolitan
#
#    Propertycount
# 0         4019.0
# 1         4019.0
# 2         4019.0
# ...

# %%
df.nunique()
# Out:
# Suburb            314
# Rooms               9
# Type                3
# Price            2204
# Method              5
# SellerG           268
# Distance          202
# Bedroom2           12
# Bathroom            9
# Car                12
# Landsize         1448
# BuildingArea      603
# CouncilArea        33
# Regionname          8
# Propertycount     311
# dtype: int64

# %%
df.shape
# Out:
# (13580, 15)

# %% [markdown]
# ## one hot encoding

# %%
df = pd.get_dummies(df , drop_first = True)

# %%
df
# Out:
#        Rooms      Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0          2  1480000.0       2.5       2.0       1.0  1.0     202.0
# 1          2  1035000.0       2.5       2.0       1.0  0.0     156.0
# 2          3  1465000.0       2.5       3.0       2.0  0.0     134.0
# 3          3   850000.0       2.5       3.0       2.0  1.0      94.0
# 4          4  1600000.0       2.5       3.0       1.0  2.0     120.0
# ...      ...        ...       ...       ...       ...  ...       ...
# 13575      4  1245000.0      16.7       4.0       2.0  2.0     652.0
# 13576      3  1031000.0       6.8       3.0       2.0  2.0     333.0
# 13577      3  1170000.0       6.8       3.0       2.0  4.0     436.0
# 13578      4  2500000.0       6.8       4.0       1.0  5.0     866.0
# 13579      4  1285000.0       6.3       4.0       1.0  1.0     362.0
#
#        BuildingArea  Propertycount  Suburb_Aberfeldie  ...  \
# 0         151.96765         4019.0              False  ...
# ...

# %%
X = df.drop('Price' , axis = 1)
y = df['Price']

# %%
X
# Out:
#        Rooms  Distance  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0          2       2.5       2.0       1.0  1.0     202.0     151.96765
# 1          2       2.5       2.0       1.0  0.0     156.0      79.00000
# 2          3       2.5       3.0       2.0  0.0     134.0     150.00000
# 3          3       2.5       3.0       2.0  1.0      94.0     151.96765
# 4          4       2.5       3.0       1.0  2.0     120.0     142.00000
# ...      ...       ...       ...       ...  ...       ...           ...
# 13575      4      16.7       4.0       2.0  2.0     652.0     151.96765
# 13576      3       6.8       3.0       2.0  2.0     333.0     133.00000
# 13577      3       6.8       3.0       2.0  4.0     436.0     151.96765
# 13578      4       6.8       4.0       1.0  5.0     866.0     157.00000
# 13579      4       6.3       4.0       1.0  1.0     362.0     112.00000
#
#        Propertycount  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# ...

# %%
y
# Out:
# 0        1480000.0
# 1        1035000.0
# 2        1465000.0
# 3         850000.0
# 4        1600000.0
#            ...
# 13575    1245000.0
# 13576    1031000.0
# 13577    1170000.0
# 13578    2500000.0
# 13579    1285000.0
# Name: Price, Length: 13580, dtype: float64

# %% [markdown]
# ### train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
X_train.head()
# Out:
#        Rooms  Distance  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 6756       2       9.5       2.0       1.0  0.0     693.0     151.96765
# 6321       3       6.5       3.0       1.0  1.0     253.0     130.00000
# 12680      2      10.1       2.0       2.0  1.0     117.0     101.00000
# 9180       4       5.3       4.0       2.0  2.0     371.0     276.00000
# 1699       3      11.4       3.0       1.0  2.0       0.0      96.00000
#
#        Propertycount  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# 6756           790.0              False                False  ...
# 6321          8870.0              False                False  ...
# 12680         7822.0              False                False  ...
# 9180         11308.0              False                False  ...
# 1699          7822.0              False                False  ...
#
#        CouncilArea_Wyndham  CouncilArea_Yarra  CouncilArea_Yarra Ranges  \
# ...

# %%
y_train.head()
# Out:
# 6756      855000.0
# 6321     1280000.0
# 12680     850000.0
# 9180     3335000.0
# 1699      820000.0
# Name: Price, dtype: float64

# %% [markdown]
# # implementing the model

# %%
linreg = LinearRegression()
linreg.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
linreg.score(X_train , y_train)
# Out:
# 0.7080660187378154

# %%
linreg.score(X_test , y_test)
# Out:
# -3070206021416.579

# %% [markdown]
# # this shows its overfitted

# %% [markdown]
# # ridge lasso l1 and l 2 norm

# %%
from sklearn.linear_model import Lasso 

lasso = Lasso()
lasso.fit(X_train , y_train)
# Out:
# Lasso()

# %%
lasso.score(X_train , y_train)
# Out:
# 0.708058204373766

# %%
lasso.score(X_test , y_test)
# Out:
# 0.6678906102943805

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(X_train,y_train)
# Out:
# Ridge()

# %%
ridge.score(X_train , y_train)
# Out:
# 0.7050737320474572

# %%
ridge.score(X_test , y_test)
# Out:
# 0.669017372181272

# %% [markdown]
# # best performance by ridge

# %% [markdown]
# #  STOCHASTIC GRADIENT DESCENT

# %%
from sklearn.linear_model import SGDRegressor 
sgd = SGDRegressor()
sgd.fit(X_train , y_train)
# Out:
# SGDRegressor()

# %%
sgd.predict(X_test)
# Out:
# array([5.45314725e+15, 1.87362091e+15, 7.94215756e+15, ...,
#        2.99715289e+15, 1.09740874e+15, 8.49525555e+15])

# %%
y_pred = sgd.predict(X_train)
score = sgd.score(X_test, y_test)
score
# Out:
# -6.080516993325966e+20

# %%
sgd.score(X_train , y_train)
# Out:
# -9.820277125812142e+19
